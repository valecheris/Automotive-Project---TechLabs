# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sb


# %matplotlib inline

# %% [markdown]
# **Data Analysis **

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1= pd.read_csv('/content/drive/MyDrive/Data-Science-project-files/uk used cars/audi.csv')

# %%
df1.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
numerical_features = df1.select_dtypes("number").columns.to_numpy()

# %%
categorical_features = df1.select_dtypes("object").columns.to_numpy()

# %%
from pandas.plotting import scatter_matrix

# %%
audi = scatter_matrix(df1[numerical_features], figsize=(10, 10))

# %%
sns.pairplot(df1, hue ='fuelType')

# %%
pearsoncorr = df1.corr(method='pearson')

# %%
pearsoncorr
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.592581 -0.789667  0.093066 -0.351281   -0.031582
# price       0.592581  1.000000 -0.535357  0.356157 -0.600334    0.591262
# mileage    -0.789667 -0.535357  1.000000 -0.166547  0.395103    0.070710
# tax         0.093066  0.356157 -0.166547  1.000000 -0.635909    0.393075
# mpg        -0.351281 -0.600334  0.395103 -0.635909  1.000000   -0.365621
# engineSize -0.031582  0.591262  0.070710  0.393075 -0.365621    1.000000

# %%
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %%
df1.shape
# Out:
# (10668, 9)

# %%
df1.info
# Out:
# <bound method DataFrame.info of       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# ...

# %%
df1.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df1.head(10)
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# 5    A1  2016  13900    Automatic    32260   Petrol   30  58.9         1.4
# 6    A6  2016  13250    Automatic    76788   Diesel   30  61.4         2.0
# 7    A4  2016  11750       Manual    75185   Diesel   20  70.6         2.0
# 8    A3  2015  10200       Manual    46112   Petrol   20  60.1         1.4
# 9    A1  2016  12000       Manual    22451   Petrol   30  55.4         1.4

# %%
df1.loc[:, df1.isnull().any()].columns
# Out:
# Index([], dtype='object')

# %%
df1['model']
# Out:
# 0         A1
# 1         A6
# 2         A1
# 3         A4
# 4         A3
#         ...
# 10663     A3
# 10664     A3
# 10665     A3
# 10666     Q3
# 10667     Q3
# Name: model, Length: 10668, dtype: object

# %%
model_df1 = df1 ['model']

# %%
model_df1.head(100)
# Out:
# 0      A1
# 1      A6
# 2      A1
# 3      A4
# 4      A3
#      ...
# 95     A6
# 96     A1
# 97     A4
# 98     A4
# 99     A4
# Name: model, Length: 100, dtype: object

# %%
type(model_df1)
# Out:
# pandas.core.series.Series

# %%
df1.tail(100)
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 10568    Q3  2016  18250    Automatic    38235   Diesel  160  50.4         2.0
# 10569    Q3  2016  17750    Automatic    39726   Diesel  145  51.4         2.0
# 10570    Q5  2019  33000    Automatic     1000   Diesel  145  38.2         2.0
# 10571    A3  2019  22500    Automatic    14924   Petrol  145  42.2         1.5
# 10572    TT  2017  21500    Automatic    22994   Petrol  165  43.5         2.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# [100 rows x 9 columns]

# %%
df1['transmission']
# Out:
# 0           Manual
# 1        Automatic
# 2           Manual
# 3        Automatic
# 4           Manual
#            ...
# 10663       Manual
# 10664       Manual
# 10665       Manual
# 10666    Automatic
# 10667       Manual
# Name: transmission, Length: 10668, dtype: object

# %%
df1['price']
# Out:
# 0        12500
# 1        16500
# 2        11000
# 3        16800
# 4        17300
#          ...
# 10663    16999
# 10664    16999
# 10665    17199
# 10666    19499
# 10667    15999
# Name: price, Length: 10668, dtype: int64

# %%
subset = df1[['price', 'transmission']]

# %%
subset.head()
# Out:
#    price transmission
# 0  12500       Manual
# 1  16500    Automatic
# 2  11000       Manual
# 3  16800    Automatic
# 4  17300       Manual

# %%
df1.describe()
# Out:
#                year          price  ...           mpg    engineSize
# count  10668.000000   10668.000000  ...  10668.000000  10668.000000
# mean    2017.100675   22896.685039  ...     50.770022      1.930709
# std        2.167494   11714.841888  ...     12.949782      0.602957
# min     1997.000000    1490.000000  ...     18.900000      0.000000
# 25%     2016.000000   15130.750000  ...     40.900000      1.500000
# 50%     2017.000000   20200.000000  ...     49.600000      2.000000
# 75%     2019.000000   27990.000000  ...     58.900000      2.000000
# max     2020.000000  145000.000000  ...    188.300000      6.300000
#
# [8 rows x 6 columns]

# %%
df14 = df1.set_index('price', True)

# %%
df14.head()
# Out:
#       model  year transmission  mileage fuelType  tax   mpg  engineSize
# price
# 12500    A1  2017       Manual    15735   Petrol  150  55.4         1.4
# 16500    A6  2016    Automatic    36203   Diesel   20  64.2         2.0
# 11000    A1  2016       Manual    29946   Petrol   30  55.4         1.4
# 16800    A4  2017    Automatic    25952   Diesel  145  67.3         2.0
# 17300    A3  2019       Manual     1998   Petrol  145  49.6         1.0

# %%
print (df14.index.max())
# Out:
# 145000

# %%
print (df14.index.min())
# Out:
# 1490

# %%
audi = df1.drop_duplicates()

# %% [markdown]
# **Data Exploration**

# %% [markdown]
# **TRANSMISSION**

# %%
df1.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df1.mpg.astype(int)
# Out:
# 0        55
# 1        64
# 2        55
# 3        67
# 4        49
#          ..
# 10663    49
# 10664    49
# 10665    49
# 10666    47
# 10667    47
# Name: mpg, Length: 10668, dtype: int64

# %%
df1.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
audi.loc[:, ['transmission', 'price']]
# Out:
#       transmission  price
# 0           Manual  12500
# 1        Automatic  16500
# 2           Manual  11000
# 3        Automatic  16800
# 4           Manual  17300
# ...            ...    ...
# 10663       Manual  16999
# 10664       Manual  16999
# 10665       Manual  17199
# 10666    Automatic  19499
# 10667       Manual  15999
#
# [10565 rows x 2 columns]

# %%
T = sns.catplot(x="transmission", y="price", kind="box", data= audi)

# %%
T.savefig('transmission-price.png')

# %%
AT = audi.loc[audi['transmission'] == 'Automatic', ['transmission', 'price']] ### AUDI CARS WITH AUTOMATIC TRANSMISSION

# %%
AT.shape
# Out:
# (2680, 2)

# %%
MT = audi.loc[audi['transmission'] == 'Manual', ['transmission', 'price']]  ### AUDI CARS WITH MANUAL TRANSMISSION

# %%
MT.shape
# Out:
# (4317, 2)

# %%
SAT = audi.loc[audi['transmission'] == 'Semi-Auto', ['transmission', 'price']] ### AUDI CARS WITH SEMI-AUTOMATIC TRANSMISSION

# %%
SAT.shape
# Out:
# (3568, 2)

# %% [markdown]
# **FUEL TYPE**

# %%
M = audi.loc[:, ['fuelType', 'price']]

# %%
M.head()
# Out:
#   fuelType  price
# 0   Petrol  12500
# 1   Diesel  16500
# 2   Petrol  11000
# 3   Diesel  16800
# 4   Petrol  17300

# %%
F = sns.catplot(x="fuelType", y="price", kind="box", data= audi) ### Price based on Fuel Type

# %%
F.savefig('Fuel-price.png')

# %%
P = M.loc[M['fuelType'] == 'Petrol', ['fuelType', 'price']] #Petrol

# %%
P.shape
# Out:
# (5000, 2)

# %%
D = M.loc[M['fuelType'] == 'Diesel', ['fuelType', 'price']] ###Diesel

# %%
D.shape
# Out:
# (5537, 2)

# %%
H = M.loc[M['fuelType'] == 'Hybrid', ['fuelType', 'price']] ####Hybrid

# %%
H.shape   ### 28 Cars are Hybrid
# Out:
# (28, 2)

# %%
 df1.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %% [markdown]
# **MILEAGE**

# %%
MG =  audi.loc[:, ['mileage', 'price']] #

# %%
MG.head() #
# Out:
#    mileage  price
# 0    15735  12500
# 1    36203  16500
# 2    29946  11000
# 3    25952  16800
# 4     1998  17300

# %%
MP = sns.relplot(x="mileage", y="price", data=MG) #

# %%
MP.savefig('Mileage-price.png')

# %% [markdown]
# **MLES PER GALLON (mpg) Vs PRICE**

# %%
G = audi.loc[:, ['mpg', 'price']] #######

# %%
G.head(20)
# Out:
#      mpg  price
# 0   55.4  12500
# 1   64.2  16500
# 2   55.4  11000
# 3   67.3  16800
# 4   49.6  17300
# 5   58.9  13900
# 6   61.4  13250
# 7   70.6  11750
# 8   60.1  10200
# 9   55.4  12000
# 10  58.9  16100
# 11  57.6  16500
# 12  52.3  17000
# 13  58.9  16400
# 14  61.4  15400
# 15  58.9  14500
# 16  53.3  15700
# 17  56.5  13900
# 18  47.1  19000
# 19  47.9  17000

# %%
GP = sns.relplot(x="mpg", y="price", data=G)              #####

# %%
GP.savefig('MPG-price.png')

# %% [markdown]
# **ENGINE SIZE VS PRICE**

# %%
E = audi.loc[:, ['engineSize', 'price']] #######

# %%
E.head()
# Out:
#    engineSize  price
# 0         1.4  12500
# 1         2.0  16500
# 2         1.4  11000
# 3         2.0  16800
# 4         1.0  17300

# %%
EP = sns.relplot(x="engineSize", y="price", data=E) #######

# %%
EP.savefig('EngineSize-Price.png')

# %% [markdown]
# **TAX VS price**

# %%
TAX = audi.loc[:, ['tax', 'price']] ######

# %%
TAX.head()
# Out:
#    tax  price
# 0  150  12500
# 1   20  16500
# 2   30  11000
# 3  145  16800
# 4  145  17300

# %%
TAXP = sns.relplot(x="tax", y="price", data=TAX) ######

# %%
TAXP.savefig('Tax-price.png')
